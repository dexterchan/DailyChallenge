# %%
from nasdaq_institutional.nasdaq_institutional_analysis  import Nasdaq_Institution_Page_Parser

# %%
nasdaq_parser = Nasdaq_Institution_Page_Parser()

# %%
df = nasdaq_parser.load_details(security="mrna", page=10)
# Out:
# /Users/dexter/sandbox/Python/DailyChallenge/jupyter/nasdaq_institutional/nasdaq_institutional_analysis.py:85: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 85 of the file /Users/dexter/sandbox/Python/DailyChallenge/jupyter/nasdaq_institutional/nasdaq_institutional_analysis.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(html)
# We are at page 1, load page 10
# Going to press 7 with distance 3
# We are at page 1, load page 10
# Going to press 7 with distance 3
# We are at page 1, load page 10
# Going to press 7 with distance 3
# We are at page 1, load page 10
# Going to press 7 with distance 3
# We are at page 7, load page 10
# Going to press 9 with distance 1
# We are at page 9, load page 10
# Going to press 10 with distance 0
# We are at page 10, load page 10

# %%
df
# Out:
#                                            OWNER NAME        DATE  \
# 0                               VONTOBEL HOLDING LTD.  06/30/2021
# 1                                   LPL FINANCIAL LLC  06/30/2021
# 2                           AMP CAPITAL INVESTORS LTD  06/30/2021
# 3                   ROYAL LONDON ASSET MANAGEMENT LTD  06/30/2021
# 4                 HEATHBRIDGE CAPITAL MANAGEMENT LTD.  06/30/2021
# 5     RAYMOND JAMES FINANCIAL SERVICES ADVISORS, INC.  06/30/2021
# 6                             CIBC WORLD MARKETS INC.  06/30/2021
# 7                                   APERIO GROUP, LLC  12/31/2020
# 8                             HANDELSBANKEN FONDER AB  06/30/2021
# 9             OREGON PUBLIC EMPLOYEES RETIREMENT FUND  06/30/2021
# 10                                       KBC GROUP NV  06/30/2021
# 11                                          AVIVA PLC  06/30/2021
# 12                         SHELTON CAPITAL MANAGEMENT  06/30/2021
# 13  FJARDE AP-FONDEN /FOURTH SWEDISH NATIONAL PENS...  06/30/2021
# 14                                       EASTERN BANK  06/30/2021
#
#     SHARES HELD  CHANGE (SHARES)  CHANGE (%)  VALUE (IN 1,000S)
# 0      128492.0          69751.0     1.18743            58582.0
# 1      125822.0          10712.0     0.09306            57365.0
# 2      124706.0          19434.0     0.18461            56856.0
# 3      121734.0          15022.0     0.14077            55501.0
# 4      120800.0         -23550.0    -0.16315            55075.0
# 5      120542.0          43594.0     0.56654            54958.0
# 6      117431.0           -147.0    -0.00125            53539.0
# 7      116442.0           8833.0     0.08208            53088.0
# 8      113998.0         -31936.0    -0.21884            51974.0
# 9      112146.0         -67911.0    -0.37716            51130.0
# 10     111372.0          15829.0     0.16567            50777.0
# 11     108972.0          13910.0     0.14633            49683.0
# 12     105501.0            588.0     0.00560            48100.0
# 13     104230.0           9300.0     0.09797            47521.0
# 14     100842.0         100842.0     0.00000            45976.0
