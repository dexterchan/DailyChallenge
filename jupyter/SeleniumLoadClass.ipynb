# %%
from nasdaq_institutional.nasdaq_institutional_analysis  import Nasdaq_Institution_Page_Parser

# %%
nasdaq_parser = Nasdaq_Institution_Page_Parser()

# %%
df = nasdaq_parser.load_details(security="mrna", page=10)
# Out:
# /Users/dexter/sandbox/Python/DailyChallenge/jupyter/nasdaq_institutional/nasdaq_institutional_analysis.py:82: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 82 of the file /Users/dexter/sandbox/Python/DailyChallenge/jupyter/nasdaq_institutional/nasdaq_institutional_analysis.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(html)
# We are at page 1, load page 10
# Going to press 7 with distance 3
# We are at page 7, load page 10
# Going to press 9 with distance 1
# We are at page 9, load page 10
# We are at page 1, load page 10
# Going to press 7 with distance 3
# We are at page 7, load page 10
# Going to press 9 with distance 1
# We are at page 9, load page 10
# Going to press 10 with distance 0
# We are at page 1, load page 10
# Going to press 7 with distance 3
# We are at page 7, load page 10
# Going to press 9 with distance 1
# We are at page 9, load page 10
# Going to press 10 with distance 0
# We are at page 10, load page 10

# %%
df
# Out:
#                                     OWNER NAME        DATE  SHARES HELD  \
# 0            COMMONWEALTH EQUITY SERVICES, LLC  06/30/2021     100441.0
# 1                   FRED ALGER MANAGEMENT, LLC  06/30/2021      98819.0
# 2                         OPPENHEIMER & CO INC  06/30/2021      90324.0
# 3                  LAZARD ASSET MANAGEMENT LLC  06/30/2021      89483.0
# 4   FIRST REPUBLIC INVESTMENT MANAGEMENT, INC.  06/30/2021      89188.0
# 5              ARIZONA STATE RETIREMENT SYSTEM  06/30/2021      88695.0
# 6                PANAGORA ASSET MANAGEMENT INC  06/30/2021      88214.0
# 7               NOMURA ASSET MANAGEMENT CO LTD  06/30/2021      86588.0
# 8                            HSBC HOLDINGS PLC  06/30/2021      85790.0
# 9                         PROFUND ADVISORS LLC  06/30/2021      84530.0
# 10          TEACHER RETIREMENT SYSTEM OF TEXAS  06/30/2021      82601.0
# 11                         APEIRON CAPITAL LTD  06/30/2021      82000.0
# 12          WORLDQUANT MILLENNIUM ADVISORS LLC  06/30/2021      80556.0
# 13             RUSSELL INVESTMENTS GROUP, LTD.  06/30/2021      79884.0
# 14  ZURCHER KANTONALBANK (ZURICH CANTONALBANK)  06/30/2021      79424.0
#
#     CHANGE (SHARES)  CHANGE (%)  VALUE (IN 1,000S)
# 0           -4930.0    -0.04679            45793.0
# 1           98819.0     0.00000            45054.0
# 2           -8470.0    -0.08573            41181.0
# 3           69859.0     3.55988            40797.0
# 4           74558.0     5.09624            40663.0
# 5           10636.0     0.13626            40438.0
# 6           -1133.0    -0.01268            40219.0
# 7           11038.0     0.14610            39477.0
# 8          -30220.0    -0.26049            39113.0
# 9           -2291.0    -0.02639            38539.0
# 10          -4368.0    -0.05022            37659.0
# 11          47000.0     1.34286            37385.0
# 12          80556.0     0.00000            36727.0
# 13           3475.0     0.04548            36421.0
# 14          20923.0     0.35765            36211.0
